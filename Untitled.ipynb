# %%
from PIL import Image

# %%
img = Image.open('/data/data/2.png')
orig_width = img.size[0]
img = img.resize((300, 80), Image.ANTIALIAS)

# %%
img.size
# Out:
# (300, 80)

# %%
img.show()

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
data = np.asarray(img)
imshow(data)

# %%
data.shape
# Out:
# (80, 300)

# %%
b = np.repeat(data[:, :, np.newaxis], 3, axis=2)

# %%
b.shape
# Out:
# (80, 300, 3)

# %%
imshow(b)

# %%
import cv2

# %%
img = cv2.imread('/data/data/1647X1060_Header.png')

# %%
imshow(img)

# %%
img.shape
# Out:
# (630, 980, 3)

# %% [markdown]
# im = Image.fromarray(img)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-6a9ab8e2fb47> in <module>
# ----> 1 im.size()
#
# NameError: name 'im' is not defined

# %%
from PIL import Image

# %%
im = Image.fromarray(img)

# %%
im.size
# Out:
# (980, 630)
